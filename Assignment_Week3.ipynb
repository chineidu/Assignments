# %%
# import the necessary libraries
import numpy as np
import pandas as pd

# import visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
# Display all the columns in the dataset
pd.set_option('max_columns', None)

# %% [markdown]
# <br>
#
# ### Assignment 1: Univariate Plotting
# #### Exercise
# Make a plot using the 'Pokemon' dataset and answer the following questions:
# * The frequency of Pokemon by type
# * The frequency of Pokemon by HP stat total
# * The frequency of Pokemon by weight

# %%
# Load the data
pkn_data = pd.read_csv('Files/pokemon.csv')

# The first 5 observations of the data
pkn_data.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# Information about the data
pkn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# <br>
#
# **Qs 1. The frequency of Pokemon by type**

# %%
pkn_data['Type 1'].value_counts().plot.bar()
plt.xlabel("Types of Pokemons", fontsize=15)
plt.ylabel("Frequency", fontsize=15)
plt.title("The Frequency of Pokemon by Type", fontsize=17)

plt.show()

# %%
(pkn_data['Type 1'].value_counts() / len(pkn_data)).plot.bar()
plt.xlabel("Types of Pokemons", fontsize=15)
plt.ylabel("Percentage of Frequency", fontsize=15)
plt.title("The Frequency of Pokemon by Type", fontsize=17)

plt.show()

# %% [markdown]
# <br>
#
# **Qs2. The frequency of Pokemon by HP stat total**

# %%
pkn_data['HP'].value_counts()[:10].sort_index().plot.bar()
plt.xlabel("HP", fontsize=15)
plt.ylabel("Frequency", fontsize=15)
plt.title("The Frequency of Pokemon by HP stat total", fontsize=17)

plt.show()

# %%
(pkn_data['HP'].value_counts()[:10].sort_index() / len(pkn_data)).plot.bar()
plt.xlabel("HP", fontsize=15)
plt.ylabel("Percentage of Frequency", fontsize=15)
plt.title("The Frequency of Pokemon by HP stat total", fontsize=17)

plt.show()

# %% [markdown]
# <br>
#
# **Qs3. The frequency of Pokemon by weight**

# %%
# The data has no column named 'weight'

# pkn_data[''].value_counts().plot.bar()

# %% [markdown]
# <br>
#
# ### Assignment 2: Multivariate Plotting
#
# Try answering the following questions.
#
# 1. What are three techniques for creating multivariate data visualziations?
# 2. Name three examples of visual variables.
# 3. How does summarization in data visualization work?

# %% [markdown]
# **Solution:**
# 1. Three tecniques for creating multivariate data visualizations are:
#
#     * Adding more variables
#     * Grouping the data
#     * Faceting
# <br>
#
# 2. Examples of visual variables are:
#
#    * Size
#    * Colour hue
#    * Shape
#    * Position
#    * Orientation
# <br>
#
# 3. Summarization: This is the process of finding a compact description of a dataset. i.e making the visualization simpler and easy to interprete. Examples include:
#     - Correlation coefficient plot (using heatmap in seaborn)
#     * Clustering

# %% [markdown]
# <br>
#
# ### Assignment 3: Plotting with Seaborn
#
# 1. A `seaborn` `countplot` is equivalent to what in `pandas`?
# 2. A `seaborn` `jointplot` which is configured with `kind='hex'` is equivalent to a what in `pandas`?
# 3. Why might a `kdeplot` not work very well for ordinal categorical data?
# 4. What does the "box" in a `boxplot` represent?

# %% [markdown]
# **Solution:**
# 1. bar plot
# 2. hex plot
# 3. `kde plot` is mostly used to smoothen grouped numerical data points (or bins). It's not suitable for ordinal categorical data.
# 4. Boxplot: It has the following
#     * minimum point
#     * maximum point
#     * 1st quartile (25th percentile)
#     * median (50th percentile)
#     * 3rd quartile (75th percentile)
#     * Interquartile Range(Q3 - Q1)
#     * outliers
#
#
# ![boxplot](https://miro.medium.com/max/18000/1*2c21SkzJMf3frPXPAR_gZA.png)
